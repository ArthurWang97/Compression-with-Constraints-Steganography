# %%
import io
import os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from scipy import fftpack
import IPython
from itertools import islice
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import pickle
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from random import shuffle

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls /content/gdrive/My\ Drive/data
# 以下是解压数据
# !unzip /content/gdrive/My\ Drive/data/train.zip
# !unzip /content/gdrive/My\ Drive/data/test.zip
# Out:
# 'Epoch N100.pkl'  'Epoch N27.pkl'  'Epoch N67.pkl'
# 'Epoch N101.pkl'  'Epoch N28.pkl'  'Epoch N68.pkl'
# 'Epoch N102.pkl'  'Epoch N29.pkl'  'Epoch N69.pkl'
# 'Epoch N103.pkl'  'Epoch N2.pkl'   'Epoch N6.pkl'
# 'Epoch N104.pkl'  'Epoch N30.pkl'  'Epoch N70.pkl'
# 'Epoch N105.pkl'  'Epoch N31.pkl'  'Epoch N71.pkl'
# 'Epoch N106.pkl'  'Epoch N32.pkl'  'Epoch N72.pkl'
# 'Epoch N107.pkl'  'Epoch N33.pkl'  'Epoch N73.pkl'
# 'Epoch N108.pkl'  'Epoch N34.pkl'  'Epoch N74.pkl'
# 'Epoch N109.pkl'  'Epoch N35.pkl'  'Epoch N75.pkl'
# 'Epoch N10.pkl'   'Epoch N36.pkl'  'Epoch N76.pkl'
# 'Epoch N110.pkl'  'Epoch N37.pkl'  'Epoch N77.pkl'
# 'Epoch N111.pkl'  'Epoch N38.pkl'  'Epoch N78.pkl'
# 'Epoch N112.pkl'  'Epoch N39.pkl'  'Epoch N79.pkl'
# 'Epoch N113.pkl'  'Epoch N3.pkl'   'Epoch N7.pkl'
# 'Epoch N114.pkl'  'Epoch N40.pkl'  'Epoch N80.pkl'
# 'Epoch N115.pkl'  'Epoch N41.pkl'  'Epoch N81.pkl'
# 'Epoch N116.pkl'  'Epoch N42.pkl'  'Epoch N82.pkl'
# 'Epoch N117.pkl'  'Epoch N43.pkl'  'Epoch N83.pkl'
# 'Epoch N118.pkl'  'Epoch N44.pkl'  'Epoch N84.pkl'
# 'Epoch N119.pkl'  'Epoch N45.pkl'  'Epoch N85.pkl'
# 'Epoch N11.pkl'   'Epoch N46.pkl'  'Epoch N86.pkl'
# 'Epoch N120.pkl'  'Epoch N47.pkl'  'Epoch N87.pkl'
# 'Epoch N121.pkl'  'Epoch N48.pkl'  'Epoch N88.pkl'
# 'Epoch N122.pkl'  'Epoch N49.pkl'  'Epoch N89.pkl'
# 'Epoch N123.pkl'  'Epoch N4.pkl'   'Epoch N8.pkl'
# 'Epoch N124.pkl'  'Epoch N50.pkl'  'Epoch N90.pkl'
# 'Epoch N125.pkl'  'Epoch N51.pkl'  'Epoch N91.pkl'
# 'Epoch N12.pkl'   'Epoch N52.pkl'  'Epoch N92.pkl'
# 'Epoch N13.pkl'   'Epoch N53.pkl'  'Epoch N93.pkl'
# 'Epoch N14.pkl'   'Epoch N54.pkl'  'Epoch N94.pkl'
# 'Epoch N15.pkl'   'Epoch N55.pkl'  'Epoch N95.pkl'
# 'Epoch N16.pkl'   'Epoch N56.pkl'  'Epoch N96.pkl'
# 'Epoch N17.pkl'   'Epoch N57.pkl'  'Epoch N97.pkl'
# 'Epoch N18.pkl'   'Epoch N58.pkl'  'Epoch N98.pkl'
# 'Epoch N19.pkl'   'Epoch N59.pkl'  'Epoch N99.pkl'
# 'Epoch N1.pkl'	  'Epoch N5.pkl'   'Epoch N9.pkl'
# 'Epoch N20.pkl'   'Epoch N60.pkl'   models2
# 'Epoch N21.pkl'   'Epoch N61.pkl'   NSL-KDD
# 'Epoch N22.pkl'   'Epoch N62.pkl'  'optimization-ii-project-3 (1).zip'
# 'Epoch N23.pkl'   'Epoch N63.pkl'   Sudoku
# 'Epoch N24.pkl'   'Epoch N64.pkl'   test.zip
# 'Epoch N25.pkl'   'Epoch N65.pkl'   tiny_magenet.zip
# 'Epoch N26.pkl'   'Epoch N66.pkl'   train.zip
# Archive:  /content/gdrive/My Drive/data/train.zip
#    creating: train/
#    creating: train/n01443537/
#   inflating: train/n01443537/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/train/
#    creating: __MACOSX/train/n01443537/
#   inflating: __MACOSX/train/n01443537/._.DS_Store
#    creating: train/n01443537/images/
#   inflating: train/n01443537/images/n01443537_192.JPEG
#    creating: __MACOSX/train/n01443537/images/
#   inflating: __MACOSX/train/n01443537/images/._n01443537_192.JPEG
#   inflating: train/n01443537/images/n01443537_184.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_184.JPEG
#   inflating: train/n01443537/images/n01443537_110.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_110.JPEG
#   inflating: train/n01443537/images/n01443537_26.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_26.JPEG
#   inflating: train/n01443537/images/n01443537_147.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_147.JPEG
#   inflating: train/n01443537/images/n01443537_71.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_71.JPEG
#   inflating: train/n01443537/images/n01443537_151.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_151.JPEG
#   inflating: train/n01443537/images/n01443537_88.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_88.JPEG
#   inflating: train/n01443537/images/n01443537_67.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_67.JPEG
#   inflating: train/n01443537/images/n01443537_106.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_106.JPEG
#   inflating: train/n01443537/images/n01443537_30.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_30.JPEG
#   inflating: train/n01443537/images/n01443537_47.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_47.JPEG
#   inflating: train/n01443537/images/n01443537_171.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_171.JPEG
#   inflating: train/n01443537/images/n01443537_3.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_3.JPEG
#   inflating: train/n01443537/images/n01443537_10.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_10.JPEG
#   inflating: train/n01443537/images/n01443537_126.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_126.JPEG
#   inflating: train/n01443537/images/n01443537_130.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_130.JPEG
#   inflating: train/n01443537/images/n01443537_188.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_188.JPEG
#   inflating: train/n01443537/images/n01443537_51.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_51.JPEG
#   inflating: train/n01443537/images/n01443537_167.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_167.JPEG
#   inflating: train/n01443537/images/n01443537_92.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_92.JPEG
#   inflating: train/n01443537/images/n01443537_84.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_84.JPEG
#   inflating: train/n01443537/images/n01443537_85.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_85.JPEG
#   inflating: train/n01443537/images/n01443537_93.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_93.JPEG
#   inflating: train/n01443537/images/.DS_Store
#   inflating: __MACOSX/train/n01443537/images/._.DS_Store
#   inflating: train/n01443537/images/n01443537_189.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_189.JPEG
#   inflating: train/n01443537/images/n01443537_50.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_50.JPEG
#   inflating: train/n01443537/images/n01443537_166.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_166.JPEG
#   inflating: train/n01443537/images/n01443537_131.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537_131.JPEG
#   inflating: train/n01443537/images/n01443537_11.JPEG
#   inflating: __MACOSX/train/n01443537/images/._n01443537
#   inflating: test/images/.DS_Store
#   inflating: __MACOSX/test/images/._.DS_Store
#   inflating: test/images/kodim11t.jpg
#   inflating: __MACOSX/test/images/._kodim11t.jpg
#   inflating: test/images/kodim07t.jpg
#   inflating: __MACOSX/test/images/._kodim07t.jpg
#   inflating: test/images/kodim20t.jpg
#   inflating: __MACOSX/test/images/._kodim20t.jpg
#   inflating: test/images/kodim16t.jpg
#   inflating: __MACOSX/test/images/._kodim16t.jpg
#   inflating: test/images/kodim17t.jpg
#   inflating: __MACOSX/test/images/._kodim17t.jpg
#   inflating: test/images/kodim01t.jpg
#   inflating: __MACOSX/test/images/._kodim01t.jpg
#   inflating: test/images/kodim21t.jpg
#   inflating: __MACOSX/test/images/._kodim21t.jpg
#   inflating: test/images/kodim18t.jpg
#   inflating: __MACOSX/test/images/._kodim18t.jpg
#   inflating: test/images/kodim22t.jpg
#   inflating: __MACOSX/test/images/._kodim22t.jpg
#   inflating: test/images/kodim14t.jpg
#   inflating: __MACOSX/test/images/._kodim14t.jpg
#   inflating: test/images/kodim02t.jpg
#   inflating: __MACOSX/test/images/._kodim02t.jpg
#   inflating: test/images/kodim03t.jpg
#   inflating: __MACOSX/test/images/._kodim03t.jpg
#   inflating: test/images/kodim15t.jpg
#   inflating: __MACOSX/test/images/._kodim15t.jpg
#   inflating: test/images/kodim23t.jpg
#   inflating: __MACOSX/test/images/._kodim23t.jpg
#   inflating: test/images/kodim19t.jpg
#   inflating: __MACOSX/test/images/._kodim19t.jpg
#   inflating: test/images/kodim12t.jpg
#   inflating: __MACOSX/test/images/._kodim12t.jpg
#   inflating: test/images/kodim04t.jpg
#   inflating: __MACOSX/test/images/._kodim04t.jpg
#   inflating: test/images/kodim08t.jpg
#   inflating: __MACOSX/test/images/._kodim08t.jpg
#   inflating: test/images/kodim24t.jpg
#   inflating: __MACOSX/test/images/._kodim24t.jpg
#   inflating: test/images/kodim09t.jpg
#   inflating: __MACOSX/test/images/._kodim09t.jpg
#   inflating: test/images/kodim05t.jpg
#   inflating: __MACOSX/test/images/._kodim05t.jpg
#   inflating: test/images/kodim13t.jpg
#   inflating: __MACOSX/test/images/._kodim13t.jpg
#   inflating: __MACOSX/._test

# %%
num_epochs = 125
batch_size = 128
learning_rate = 0.001
beta = 1

# Mean and std deviation of imagenet dataset. Source: http://cs231n.stanford.edu/reports/2017/pdfs/101.pdf
std = [0.229, 0.224, 0.225]
mean = [0.485, 0.456, 0.406]

# TODO: Define train, validation and models
cmd = '/content'
MODELS_PATH = '/content/gdrive/My Drive/data/'
# TRAIN_PATH = cwd+'/train/'
# VALID_PATH = cwd+'/valid/'
#VALID_PATH = cwd+'/sample/valid/'
TRAIN_PATH = cmd+'/train'
TEST_PATH = cmd + '/test'

DEVICE = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
if not os.path.exists(MODELS_PATH): os.mkdir(MODELS_PATH)

# %%
def customized_loss(S_prime, C_prime, S, C, B):
    ''' Calculates loss specified on the paper.'''
    
    loss_cover = torch.nn.functional.mse_loss(C_prime, C)
    loss_secret = torch.nn.functional.mse_loss(S_prime, S)
    loss_all = loss_cover + B * loss_secret
    return loss_all, loss_cover, loss_secret

# %%
class PrepNetwork(nn.Module):
    def __init__(self):
        super(PrepNetwork, self).__init__()
        self.initialP3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialP4 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialP5 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalP3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalP4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalP5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        
    def forward(self, p):
       # p=fftpack.dct(fftpack.dct(p.T, norm='ortho').T, norm='ortho')
        p1 = self.initialP3(p)
        p2 = self.initialP4(p)
        p3 = self.initialP5(p)
        mid = torch.cat((p1, p2, p3), 1)
        p4 = self.finalP3(mid)
        p5 = self.finalP4(mid)
        p6 = self.finalP5(mid)
        out = torch.cat((p4, p5, p6), 1)
        return out
    
class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.initialH3 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialH4 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialH5 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalH4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalH5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0))
        
    def forward(self, h):
       # h=get_2D_dct(h)
        
        h1 = self.initialH3(h)
        h2 = self.initialH4(h)
        h3 = self.initialH5(h)
        mid = torch.cat((h1, h2, h3), 1)
        h4 = self.finalH3(mid)
        h5 = self.finalH4(mid)
        h6 = self.finalH5(mid)
        mid2 = torch.cat((h4, h5, h6), 1)
        out = self.finalH(mid2)
        out_noise = gaussian(out.data, 0, 0.1)
        return out, out_noise



class RevealNetwork(nn.Module):
    def __init__(self):
        super(RevealNetwork, self).__init__()
        self.initialR3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialR4 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialR5 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalR4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalR5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0))

    def forward(self, r):
     #   r=get_2D_dct(r)
        r1 = self.initialR3(r)
        r2 = self.initialR4(r)
        r3 = self.initialR5(r)
        mid = torch.cat((r1, r2, r3), 1)
        r4 = self.finalR3(mid)
        r5 = self.finalR4(mid)
        r6 = self.finalR5(mid)
        mid2 = torch.cat((r4, r5, r6), 1)
        out = self.finalR(mid2)
        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.m1 = PrepNetwork()
        self.m2 = HidingNetwork()
        self.m3 = RevealNetwork()

    def forward(self, secret, cover):
        x_1 = self.m1(secret)
        mid = torch.cat((x_1, cover), 1)
        x_2, x_2_noise = self.m2(mid)
        x_3 = self.m3(x_2_noise)
        return x_2, x_3

# %%
def denormalize(image, std, mean):
    ''' Denormalizes a tensor of images.'''

    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image

def imshow(img, idx, learning_rate, beta):
    '''Prints out an image given in tensor format.'''
    
    img = denormalize(img, std, mean)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title('Example '+str(idx)+', lr='+str(learning_rate)+', B='+str(beta))
    plt.show()
    return

def gaussian(tensor, mean=0, stddev=0.1):
    '''Adds random noise to a tensor.'''
    
    noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1).to(DEVICE)
    return Variable(tensor + noise)

def get_2D_dct(img):
    """ Get 2D Cosine Transform of Image
    """
    return fftpack.dct(fftpack.dct(img.T, norm='ortho').T, norm='ortho')

# %%
net = Net().to(DEVICE)
#Creates training set
train_loader = torch.utils.data.DataLoader(
        datasets.ImageFolder(
        TRAIN_PATH,
        transforms.Compose([
        transforms.Resize(64),
        transforms.RandomCrop(64),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ])), batch_size=batch_size, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# Creates test set
test_loader = torch.utils.data.DataLoader(
        datasets.ImageFolder(
        TEST_PATH, 
        transforms.Compose([
        transforms.Resize(64),
        transforms.RandomCrop(64),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ])), batch_size=2, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# %%
def train_model(train_loader, beta, learning_rate):
    
    # Save optimizer
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    
    loss_history = []
    # Iterate over batches performing forward and backward passes
    for epoch in range(num_epochs):

        # Train mode
        net.train()
        
        train_losses = []
        # Train one epoch
        for idx, train_batch in enumerate(train_loader):

            data, _  = train_batch
            data = data.to(DEVICE)

            # Saves secret images and secret covers
            train_covers = data[:len(data)//2]
            train_secrets = data[len(data)//2:]
            
            # Creates variable from secret and cover images
            train_secrets = torch.tensor(train_secrets, requires_grad=False)
            train_covers = torch.tensor(train_covers, requires_grad=False)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            train_hidden, train_output = net(train_secrets, train_covers)

            # Calculate loss and perform backprop
            train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output, train_hidden, train_secrets, train_covers, beta)
            train_loss.backward()
            optimizer.step()
            
            # Saves training loss
            # print(train_loss.data)
            train_losses.append(torch.Tensor.item(train_loss.data))
            loss_history.append(torch.Tensor.item(train_loss.data))
            
            # Prints mini-batch losses
            print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), (torch.Tensor.item(train_loss.data)), torch.Tensor.item(train_loss_cover.data), torch.Tensor.item(train_loss_secret.data)))
    
        torch.save(net.state_dict(), MODELS_PATH+'Epoch N{}.pkl'.format(epoch+1))
        
        mean_train_loss = np.mean(train_losses)
    
        # Prints epoch average loss
        print ('Epoch [{0}/{1}], Average_loss: {2:.4f}'.format(
                epoch+1, num_epochs, mean_train_loss))
    
    return net, mean_train_loss, loss_history

# %%
net, mean_train_loss, loss_history = train_model(train_loader, beta, learning_rate)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Training: Batch 1/3. Loss of 2.6521, cover loss of 1.3059, secret loss of 1.3462
# Training: Batch 2/3. Loss of 2.6695, cover loss of 1.3189, secret loss of 1.3507
# Training: Batch 3/3. Loss of 2.4602, cover loss of 1.1872, secret loss of 1.2730
# Epoch [1/125], Average_loss: 2.5939
# Training: Batch 1/3. Loss of 2.3827, cover loss of 1.1615, secret loss of 1.2212
# Training: Batch 2/3. Loss of 2.2566, cover loss of 0.9465, secret loss of 1.3101
# Training: Batch 3/3. Loss of 2.0112, cover loss of 0.7355, secret loss of 1.2757
# Epoch [2/125], Average_loss: 2.2168
# Training: Batch 1/3. Loss of 1.9127, cover loss of 0.5309, secret loss of 1.3818
# Training: Batch 2/3. Loss of 1.8814, cover loss of 0.5621, secret loss of 1.3193
# Training: Batch 3/3. Loss of 1.8808, cover loss of 0.5162, secret loss of 1.3646
# Epoch [3/125], Average_loss: 1.8916
# Training: Batch 1/3. Loss of 1.7026, cover loss of 0.4766, secret loss of 1.2260
# Training: Batch 2/3. Loss of 1.9872, cover loss of 0.4998, secret loss of 1.4874
# Training: Batch 3/3. Loss of 1.6347, cover loss of 0.4555, secret loss of 1.1791
# Epoch [4/125], Average_loss: 1.7748
# Training: Batch 1/3. Loss of 1.6342, cover loss of 0.3577, secret loss of 1.2765
# Training: Batch 2/3. Loss of 1.7029, cover loss of 0.3239, secret loss of 1.3790
# Training: Batch 3/3. Loss of 1.6531, cover loss of 0.3180, secret loss of 1.3351
# Epoch [5/125], Average_loss: 1.6634
# Training: Batch 1/3. Loss of 1.7133, cover loss of 0.3301, secret loss of 1.3832
# Training: Batch 2/3. Loss of 1.6039, cover loss of 0.2818, secret loss of 1.3221
# Training: Batch 3/3. Loss of 1.4993, cover loss of 0.2750, secret loss of 1.2243
# Epoch [6/125], Average_loss: 1.6055
# Training: Batch 1/3. Loss of 1.6368, cover loss of 0.2410, secret loss of 1.3958
# Training: Batch 2/3. Loss of 1.5923, cover loss of 0.3094, secret loss of 1.2829
# Training: Batch 3/3. Loss of 1.6587, cover loss of 0.2711, secret loss of 1.3877
# Epoch [7/125], Average_loss: 1.6293
# Training: Batch 1/3. Loss of 1.6883, cover loss of 0.2882, secret loss of 1.4001
# Training: Batch 2/3. Loss of 1.6464, cover loss of 0.2562, secret loss of 1.3902
# Training: Batch 3/3. Loss of 1.5292, cover loss of 0.2520, secret loss of 1.2772
# Epoch [8/125], Average_loss: 1.6213
# Training: Batch 1/3. Loss of 1.6996, cover loss of 0.2695, secret loss of 1.4301
# Training: Batch 2/3. Loss of 1.4963, cover loss of 0.2492, secret loss of 1.2472
# Training: Batch 3/3. Loss of 1.3942, cover loss of 0.2373, secret loss of 1.1568
# Epoch [9/125], Average_loss: 1.5300
# Training: Batch 1/3. Loss of 1.6668, cover loss of 0.2574, secret loss of 1.4093
# Training: Batch 2/3. Loss of 1.4974, cover loss of 0.2453, secret loss of 1.2521
# Training: Batch 3/3. Loss of 1.5647, cover loss of 0.2473, secret loss of 1.3173
# Epoch [10/125], Average_loss: 1.5763
# Training: Batch 1/3. Loss of 1.4919, cover loss of 0.2455, secret loss of 1.2464
# Training: Batch 2/3. Loss of 1.5749, cover loss of 0.2251, secret loss of 1.3498
# Training: Batch 3/3. Loss of 1.6274, cover loss of 0.2208, secret loss of 1.4066
# Epoch [11/125], Average_loss: 1.5647
# Training: Batch 1/3. Loss of 1.5232, cover loss of 0.2220, secret loss of 1.3013
# Training: Batch 2/3. Loss of 1.6275, cover loss of 0.2228, secret loss of 1.4047
# Training: Batch 3/3. Loss of 1.4818, cover loss of 0.1868, secret loss of 1.2950
# Epoch [12/125], Average_loss: 1.5442
# Training: Batch 1/3. Loss of 1.6020, cover loss of 0.2102, secret loss of 1.3918
# Training: Batch 2/3. Loss of 1.5205, cover loss of 0.1886, secret loss of 1.3319
# Training: Batch 3/3. Loss of 1.4566, cover loss of 0.2092, secret loss of 1.2474
# Epoch [13/125], Average_loss: 1.5264
# Training: Batch 1/3. Loss of 1.5046, cover loss of 0.1860, secret loss of 1.3186
# Training: Batch 2/3. Loss of 1.6108, cover loss of 0.1898, secret loss of 1.4210
# Training: Batch 3/3. Loss of 1.6036, cover loss of 0.1698, secret loss of 1.4337
# Epoch [14/125], Average_loss: 1.5730
# Training: Batch 1/3. Loss of 1.4717, cover loss of 0.1746, secret loss of 1.2971
# Training: Batch 2/3. Loss of 1.4207, cover loss of 0.1851, secret loss of 1.2355
# Training: Batch 3/3. Loss of 1.4783, cover loss of 0.1705, secret loss of 1.3077
# Epoch [15/125], Average_loss: 1.4569
# Training: Batch 1/3. Loss of 1.5287, cover loss of 0.1733, secret loss of 1.3554
# Training: Batch 2/3. Loss of 1.4892, cover loss of 0.1802, secret loss of 1.3091
# Training: Batch 3/3. Loss of 1.4093, cover loss of 0.1558, secret loss of 1.2535
# Epoch [16/125], Average_loss: 1.4757
# Training: Batch 1/3. Loss of 1.6405, cover loss of 0.1621, secret loss of 1.4784
# Training: Batch 2/3. Loss of 1.5345, cover loss of 0.1746, secret loss of 1.3599
# Training: Batch 3/3. Loss of 1.4969, cover loss of 0.1451, secret loss of 1.3518
# Epoch [17/125], Average_loss: 1.5573
# Training: Batch 1/3. Loss of 1.4261, cover loss of 0.1542, secret loss of 1.2718
# Training: Batch 2/3. Loss of 1.3225, cover loss of 0.1497, secret loss of 1.1728
# Training: Batch 3/3. Loss of 1.7120, cover loss of 0.1654, secret loss of 1.5466
# Epoch [18/125], Average_loss: 1.4868
# Training: Batch 1/3. Loss of 1.4886, cover loss of 0.1536, secret loss of 1.3350
# Training: Batch 2/3. Loss of 1.4857, cover loss of 0.1270, secret loss of 1.3587
# Training: Batch 3/3. Loss of 1.3629, cover loss of 0.1374, secret loss of 1.2255
# Epoch [19/125], Average_loss: 1.4457
# Training: Batch 1/3. Loss of 1.5716, cover loss of 0.1427, secret loss of 1.4290
# Training: Batch 2/3. Loss of 1.4606, cover loss of 0.1475, secret loss of 1.3131
# Training: Batch 3/3. Loss of 1.4342, cover loss of 0.1503, secret loss of 1.2839
# Epoch [20/125], Average_loss: 1.4888
# Training: Batch 1/3. Loss of 1.4840, cover loss of 0.1110, secret loss of 1.3730
# Training: Batch 2/3. Loss of 1.5035, cover loss of 0.1278, secret loss of 1.3757
# Training: Batch 3/3. Loss of 1.4134, cover loss of 0.1523, secret loss of 1.2612
# Epoch [21/125], Average_loss: 1.4670
# Training: Batch 1/3. Loss of 1.5069, cover loss of 0.1345, secret loss of 1.3724
# Training: Batch 2/3. Loss of 1.4358, cover loss of 0.1311, secret loss of 1.3048
# Training: Batch 3/3. Loss of 1.3590, cover loss of 0.1312, secret loss of 1.2278
# Epoch [22/125], Average_loss: 1.4339
# Training: Batch 1/3. Loss of 1.3156, cover loss of 0.1277, secret loss of 1.1879
# Training: Batch 2/3. Loss of 1.3953, cover loss of 0.1117, secret loss of 1.2836
# Training: Batch 3/3. Loss of 1.4248, cover loss of 0.1272, secret loss of 1.2976
# Epoch [23/125], Average_loss: 1.3786
# Training: Batch 1/3. Loss of 1.4411, cover loss of 0.1238, secret loss of 1.3173
# Training: Batch 2/3. Loss of 1.4967, cover loss of 0.1309, secret loss of 1.3659
# Training: Batch 3/3. Loss of 1.3156, cover loss of 0.1166, secret loss of 1.1991
# Epoch [24/125], Average_loss: 1.4178
# Training: Batch 1/3. Loss of 1.4107, cover loss of 0.1194, secret loss of 1.2913
# Training: Batch 2/3. Loss of 1.2814, cover loss of 0.1061, secret loss of 1.1753
# Training: Batch 3/3. Loss of 1.4670, cover loss of 0.1070, secret loss of 1.3599
# Epoch [25/125], Average_loss: 1.3863
# Training: Batch 1/3. Loss of 1.3650, cover loss of 0.1071, secret loss of 1.2579
# Training: Batch 2/3. Loss of 1.6028, cover loss of 0.1062, secret loss of 1.4966
# Training: Batch 3/3. Loss of 1.3470, cover loss of 0.0975, secret loss of 1.2495
# Epoch [26/125], Average_loss: 1.4383
# Training: Batch 1/3. Loss of 1.3847, cover loss of 0.0884, secret loss of 1.2963
# Training: Batch 2/3. Loss of 1.3707, cover loss of 0.0848, secret loss of 1.2859
# Training: Batch 3/3. Loss of 1.4790, cover loss of 0.0902, secret loss of 1.3888
# Epoch [27/125], Average_loss: 1.4115
# Training: Batch 1/3. Loss of 1.5080, cover loss of 0.0922, secret loss of 1.4159
# Training: Batch 2/3. Loss of 1.3798, cover loss of 0.0954, secret loss of 1.2844
# Training: Batch 3/3. Loss of 1.4711, cover loss of 0.0919, secret loss of 1.3792
# Epoch [28/125], Average_loss: 1.4529
# Training: Batch 1/3. Loss of 1.3442, cover loss of 0.0875, secret loss of 1.2567
# Training: Batch 2/3. Loss of 1.6153, cover loss of 0.0828, secret loss of 1.5325
# Training: Batch 3/3. Loss of 1.3517, cover loss of 0.0830, secret loss of 1.2687
# Epoch [29/125], Average_loss: 1.4371
# Training: Batch 1/3. Loss of 1.4203, cover loss of 0.0924, secret loss of 1.3279
# Training: Batch 2/3. Loss of 1.5493, cover loss of 0.0717, secret loss of 1.4776
# Training: Batch 3/3. Loss of 1.3376, cover loss of 0.0836, secret loss of 1.2540
# Epoch [30/125], Average_loss: 1.4357
# Training: Batch 1/3. Loss of 1.4915, cover loss of 0.0759, secret loss of 1.4156
# Training: Batch 2/3. Loss of 1.3254, cover loss of 0.0900, secret loss of 1.2354
# Training: Batch 3/3. Loss of 1.3536, cover loss of 0.0895, secret loss of 1.2641
# Epoch [31/125], Average_loss: 1.3902
# Training: Batch 1/3. Loss of 1.3987, cover loss of 0.0824, secret loss of 1.3163
# Training: Batch 2/3. Loss of 1.3983, cover loss of 0.0733, secret loss of 1.3250
# Training: Batch 3/3. Loss of 1.3138, cover loss of 0.0731, secret loss of 1.2407
# Epoch [32/125], Average_loss: 1.3703
# Training: Batch 1/3. Loss of 1.4150, cover loss of 0.0655, secret loss of 1.3495
# Training: Batch 2/3. Loss of 1.2871, cover loss of 0.0622, secret loss of 1.2249
# Training: Batch 3/3. Loss of 1.4021, cover loss of 0.0781, secret loss of 1.3240
# Epoch [33/125], Average_loss: 1.3681
# Training: Batch 1/3. Loss of 1.3040, cover loss of 0.0698, secret loss of 1.2341
# Training: Batch 2/3. Loss of 1.3019, cover loss of 0.0671, secret loss of 1.2349
# Training: Batch 3/3. Loss of 1.3340, cover loss of 0.0602, secret loss of 1.2738
# Epoch [34/125], Average_loss: 1.3133
# Training: Batch 1/3. Loss of 1.3388, cover loss of 0.0681, secret loss of 1.2707
# Training: Batch 2/3. Loss of 1.4611, cover loss of 0.0664, secret loss of 1.3947
# Training: Batch 3/3. Loss of 1.3795, cover loss of 0.0607, secret loss of 1.3188
# Epoch [35/125], Average_loss: 1.3931
# Training: Batch 1/3. Loss of 1.2323, cover loss of 0.0653, secret loss of 1.1671
# Training: Batch 2/3. Loss of 1.3893, cover loss of 0.0636, secret loss of 1.3257
# Training: Batch 3/3. Loss of 1.2340, cover loss of 0.0622, secret loss of 1.1717
# Epoch [36/125], Average_loss: 1.2852
# Training: Batch 1/3. Loss of 1.2132, cover loss of 0.0664, secret loss of 1.1468
# Training: Batch 2/3. Loss of 1.4023, cover loss of 0.0647, secret loss of 1.3375
# Training: Batch 3/3. Loss of 1.2864, cover loss of 0.0588, secret loss of 1.2276
# Epoch [37/125], Average_loss: 1.3006
# Training: Batch 1/3. Loss of 1.3283, cover loss of 0.0606, secret loss of 1.2677
# Training: Batch 2/3. Loss of 1.3196, cover loss of 0.0573, secret loss of 1.2623
# Training: Batch 3/3. Loss of 1.3750, cover loss of 0.0643, secret loss of 1.3107
# Epoch [38/125], Average_loss: 1.3410
# Training: Batch 1/3. Loss of 1.4972, cover loss of 0.0511, secret loss of 1.4461
# Training: Batch 2/3. Loss of 1.6333, cover loss of 0.0573, secret loss of 1.5760
# Training: Batch 3/3. Loss of 1.3135, cover loss of 0.0470, secret loss of 1.2666
# Epoch [39/125], Average_loss: 1.4813
# Training: Batch 1/3. Loss of 1.3977, cover loss of 0.0523, secret loss of 1.3454
# Training: Batch 2/3. Loss of 1.3405, cover loss of 0.0532, secret loss of 1.2873
# Training: Batch 3/3. Loss of 1.4284, cover loss of 0.0568, secret loss of 1.3716
# Epoch [40/125], Average_loss: 1.3888
# Training: Batch 1/3. Loss of 1.1192, cover loss of 0.0487, secret loss of 1.0705
# Training: Batch 2/3. Loss of 1.2918, cover loss of 0.0517, secret loss of 1.2402
# Training: Batch 3/3. Loss of 1.3889, cover loss of 0.0495, secret loss of 1.3395
# Epoch [41/125], Average_loss: 1.2667
# Training: Batch 1/3. Loss of 1.3094, cover loss of 0.0474, secret loss of 1.2621
# Training: Batch 2/3. Loss of 1.4171, cover loss of 0.0480, secret loss of 1.3691
# Training: Batch 3/3. Loss of 1.2591, cover loss of 0.0465, secret loss of 1.2126
# Epoch [42/125], Average_loss: 1.3286
# Training: Batch 1/3. Loss of 1.3935, cover loss of 0.0497, secret loss of 1.3438
# Training: Batch 2/3. Loss of 1.4287, cover loss of 0.0445, secret loss of 1.3842
# Training: Batch 3/3. Loss of 1.3268, cover loss of 0.0455, secret loss of 1.2813
# Epoch [43/125], Average_loss: 1.3830
# Training: Batch 1/3. Loss of 1.3153, cover loss of 0.0421, secret loss of 1.2732
# Training: Batch 2/3. Loss of 1.4096, cover loss of 0.0385, secret loss of 1.3711
# Training: Batch 3/3. Loss of 1.6911, cover loss of 0.0473, secret loss of 1.6438
# Epoch [44/125], Average_loss: 1.4720
# Training: Batch 1/3. Loss of 1.3104, cover loss of 0.0421, secret loss of 1.2684
# Training: Batch 2/3. Loss of 1.5070, cover loss of 0.0371, secret loss of 1.4699
# Training: Batch 3/3. Loss of 1.3924, cover loss of 0.0387, secret loss of 1.3538
# Epoch [45/125], Average_loss: 1.4033
# Training: Batch 1/3. Loss of 1.2241, cover loss of 0.0363, secret loss of 1.1879
# Training: Batch 2/3. Loss of 1.2886, cover loss of 0.0352, secret loss of 1.2534
# Training: Batch 3/3. Loss of 1.3642, cover loss of 0.0382, secret loss of 1.3259
# Epoch [46/125], Average_loss: 1.2923
# Training: Batch 1/3. Loss of 1.2417, cover loss of 0.0394, secret loss of 1.2024
# Training: Batch 2/3. Loss of 1.4164, cover loss of 0.0293, secret loss of 1.3872
# Training: Batch 3/3. Loss of 1.4492, cover loss of 0.0324, secret loss of 1.4168
# Epoch [47/125], Average_loss: 1.3691
# Training: Batch 1/3. Loss of 1.3219, cover loss of 0.0329, secret loss of 1.2890
# Training: Batch 2/3. Loss of 1.3151, cover loss of 0.0331, secret loss of 1.2820
# Training: Batch 3/3. Loss of 1.2585, cover loss of 0.0392, secret loss of 1.2193
# Epoch [48/125], Average_loss: 1.2985
# Training: Batch 1/3. Loss of 1.3972, cover loss of 0.0402, secret loss of 1.3570
# Training: Batch 2/3. Loss of 1.3407, cover loss of 0.0454, secret loss of 1.2953
# Training: Batch 3/3. Loss of 1.3998, cover loss of 0.0324, secret loss of 1.3674
# Epoch [49/125], Average_loss: 1.3792
# Training: Batch 1/3. Loss of 1.4797, cover loss of 0.0397, secret loss of 1.4400
# Training: Batch 2/3. Loss of 1.3140, cover loss of 0.0383, secret loss of 1.2757
# Training: Batch 3/3. Loss of 1.2538, cover loss of 0.0377, secret loss of 1.2161
# Epoch [50/125], Average_loss: 1.3492
# Training: Batch 1/3. Loss of 1.5113, cover loss of 0.0348, secret loss of 1.4765
# Training: Batch 2/3. Loss of 1.2272, cover loss of 0.0326, secret loss of 1.1946
# Training: Batch 3/3. Loss of 1.4813, cover loss of 0.0329, secret loss of 1.4484
# Epoch [51/125], Average_loss: 1.4066
# Training: Batch 1/3. Loss of 1.3622, cover loss of 0.0325, secret loss of 1.3296
# Training: Batch 2/3. Loss of 1.3156, cover loss of 0.0277, secret loss of 1.2879
# Training: Batch 3/3. Loss of 1.2187, cover loss of 0.0335, secret loss of 1.1852
# Epoch [52/125], Average_loss: 1.2988
# Training: Batch 1/3. Loss of 1.2761, cover loss of 0.0249, secret loss of 1.2513
# Training: Batch 2/3. Loss of 1.3278, cover loss of 0.0283, secret loss of 1.2996
# Training: Batch 3/3. Loss of 1.4623, cover loss of 0.0306, secret loss of 1.4317
# Epoch [53/125], Average_loss: 1.3554
# Training: Batch 1/3. Loss of 1.2988, cover loss of 0.0271, secret loss of 1.2718
# Training: Batch 2/3. Loss of 1.3791, cover loss of 0.0258, secret loss of 1.3533
# Training: Batch 3/3. Loss of 1.2873, cover loss of 0.0236, secret loss of 1.2637
# Epoch [54/125], Average_loss: 1.3217
# Training: Batch 1/3. Loss of 1.3763, cover loss of 0.0244, secret loss of 1.3518
# Training: Batch 2/3. Loss of 1.3112, cover loss of 0.0241, secret loss of 1.2871
# Training: Batch 3/3. Loss of 1.4023, cover loss of 0.0206, secret loss of 1.3818
# Epoch [55/125], Average_loss: 1.3633
# Training: Batch 1/3. Loss of 1.4362, cover loss of 0.0216, secret loss of 1.4146
# Training: Batch 2/3. Loss of 1.4097, cover loss of 0.0235, secret loss of 1.3862
# Training: Batch 3/3. Loss of 1.2948, cover loss of 0.0232, secret loss of 1.2716
# Epoch [56/125], Average_loss: 1.3802
# Training: Batch 1/3. Loss of 1.2877, cover loss of 0.0195, secret loss of 1.2682
# Training: Batch 2/3. Loss of 1.2273, cover loss of 0.0201, secret loss of 1.2071
# Training: Batch 3/3. Loss of 1.4139, cover loss of 0.0185, secret loss of 1.3953
# Epoch [57/125], Average_loss: 1.3096
# Training: Batch 1/3. Loss of 1.2253, cover loss of 0.0153, secret loss of 1.2099
# Training: Batch 2/3. Loss of 1.4409, cover loss of 0.0200, secret loss of 1.4210
# Training: Batch 3/3. Loss of 1.5181, cover loss of 0.0169, secret loss of 1.5012
# Epoch [58/125], Average_loss: 1.3948
# Training: Batch 1/3. Loss of 1.2814, cover loss of 0.0175, secret loss of 1.2639
# Training: Batch 2/3. Loss of 1.3022, cover loss of 0.0158, secret loss of 1.2863
# Training: Batch 3/3. Loss of 1.4230, cover loss of 0.0150, secret loss of 1.4081
# Epoch [59/125], Average_loss: 1.3355
# Training: Batch 1/3. Loss of 1.3849, cover loss of 0.0155, secret loss of 1.3694
# Training: Batch 2/3. Loss of 1.2590, cover loss of 0.0145, secret loss of 1.2445
# Training: Batch 3/3. Loss of 1.2623, cover loss of 0.0141, secret loss of 1.2482
# Epoch [60/125], Average_loss: 1.3021
# Training: Batch 1/3. Loss of 1.4481, cover loss of 0.0153, secret loss of 1.4328
# Training: Batch 2/3. Loss of 1.3536, cover loss of 0.0194, secret loss of 1.3342
# Training: Batch 3/3. Loss of 1.2494, cover loss of 0.0238, secret loss of 1.2256
# Epoch [61/125], Average_loss: 1.3504
# Training: Batch 1/3. Loss of 1.2765, cover loss of 0.0217, secret loss of 1.2548
# Training: Batch 2/3. Loss of 1.2728, cover loss of 0.0121, secret loss of 1.2607
# Training: Batch 3/3. Loss of 1.4631, cover loss of 0.0237, secret loss of 1.4394
# Epoch [62/125], Average_loss: 1.3375
# Training: Batch 1/3. Loss of 1.3431, cover loss of 0.0201, secret loss of 1.3229
# Training: Batch 2/3. Loss of 1.0594, cover loss of 0.0134, secret loss of 1.0460
# Training: Batch 3/3. Loss of 1.2718, cover loss of 0.0169, secret loss of 1.2549
# Epoch [63/125], Average_loss: 1.2248
# Training: Batch 1/3. Loss of 1.1813, cover loss of 0.0116, secret loss of 1.1697
# Training: Batch 2/3. Loss of 1.3384, cover loss of 0.0141, secret loss of 1.3243
# Training: Batch 3/3. Loss of 1.1909, cover loss of 0.0145, secret loss of 1.1764
# Epoch [64/125], Average_loss: 1.2369
# Training: Batch 1/3. Loss of 1.1438, cover loss of 0.0109, secret loss of 1.1330
# Training: Batch 2/3. Loss of 1.3812, cover loss of 0.0134, secret loss of 1.3679
# Training: Batch 3/3. Loss of 1.3191, cover loss of 0.0115, secret loss of 1.3076
# Epoch [65/125], Average_loss: 1.2814
# Training: Batch 1/3. Loss of 1.2668, cover loss of 0.0113, secret loss of 1.2554
# Training: Batch 2/3. Loss of 1.2801, cover loss of 0.0097, secret loss of 1.2704
# Training: Batch 3/3. Loss of 1.2183, cover loss of 0.0107, secret loss of 1.2076
# Epoch [66/125], Average_loss: 1.2551
# Training: Batch 1/3. Loss of 1.4277, cover loss of 0.0095, secret loss of 1.4181
# Training: Batch 2/3. Loss of 1.1528, cover loss of 0.0081, secret loss of 1.1448
# Training: Batch 3/3. Loss of 1.3826, cover loss of 0.0108, secret loss of 1.3718
# Epoch [67/125], Average_loss: 1.3210
# Training: Batch 1/3. Loss of 1.4451, cover loss of 0.0081, secret loss of 1.4371
# Training: Batch 2/3. Loss of 1.3278, cover loss of 0.0098, secret loss of 1.3180
# Training: Batch 3/3. Loss of 1.2264, cover loss of 0.0097, secret loss of 1.2167
# Epoch [68/125], Average_loss: 1.3331
# Training: Batch 1/3. Loss of 1.4801, cover loss of 0.0084, secret loss of 1.4716
# Training: Batch 2/3. Loss of 1.2934, cover loss of 0.0096, secret loss of 1.2838
# Training: Batch 3/3. Loss of 1.2219, cover loss of 0.0076, secret loss of 1.2143
# Epoch [69/125], Average_loss: 1.3318
# Training: Batch 1/3. Loss of 1.3442, cover loss of 0.0072, secret loss of 1.3370
# Training: Batch 2/3. Loss of 1.3671, cover loss of 0.0072, secret loss of 1.3599
# Training: Batch 3/3. Loss of 1.3007, cover loss of 0.0066, secret loss of 1.2941
# Epoch [70/125], Average_loss: 1.3373
# Training: Batch 1/3. Loss of 1.4043, cover loss of 0.0065, secret loss of 1.3978
# Training: Batch 2/3. Loss of 1.3917, cover loss of 0.0073, secret loss of 1.3844
# Training: Batch 3/3. Loss of 1.3993, cover loss of 0.0066, secret loss of 1.3928
# Epoch [71/125], Average_loss: 1.3984
# Training: Batch 1/3. Loss of 1.3766, cover loss of 0.0069, secret loss of 1.3697
# Training: Batch 2/3. Loss of 1.2570, cover loss of 0.0065, secret loss of 1.2505
# Training: Batch 3/3. Loss of 1.3738, cover loss of 0.0069, secret loss of 1.3669
# Epoch [72/125], Average_loss: 1.3358
# Training: Batch 1/3. Loss of 1.5374, cover loss of 0.0089, secret loss of 1.5286
# Training: Batch 2/3. Loss of 1.2554, cover loss of 0.0070, secret loss of 1.2484
# Training: Batch 3/3. Loss of 1.1565, cover loss of 0.0059, secret loss of 1.1506
# Epoch [73/125], Average_loss: 1.3165
# Training: Batch 1/3. Loss of 1.2816, cover loss of 0.0063, secret loss of 1.2753
# Training: Batch 2/3. Loss of 1.3908, cover loss of 0.0067, secret loss of 1.3841
# Training: Batch 3/3. Loss of 1.3444, cover loss of 0.0069, secret loss of 1.3375
# Epoch [74/125], Average_loss: 1.3390
# Training: Batch 1/3. Loss of 1.2881, cover loss of 0.0070, secret loss of 1.2811
# Training: Batch 2/3. Loss of 1.3839, cover loss of 0.0083, secret loss of 1.3756
# Training: Batch 3/3. Loss of 1.3050, cover loss of 0.0067, secret loss of 1.2982
# Epoch [75/125], Average_loss: 1.3257
# Training: Batch 1/3. Loss of 1.3965, cover loss of 0.0077, secret loss of 1.3888
# Training: Batch 2/3. Loss of 1.2092, cover loss of 0.0057, secret loss of 1.2035
# Training: Batch 3/3. Loss of 1.3557, cover loss of 0.0067, secret loss of 1.3490
# Epoch [76/125], Average_loss: 1.3205
# Training: Batch 1/3. Loss of 1.2604, cover loss of 0.0065, secret loss of 1.2539
# Training: Batch 2/3. Loss of 1.2813, cover loss of 0.0074, secret loss of 1.2739
# Training: Batch 3/3. Loss of 1.3115, cover loss of 0.0077, secret loss of 1.3038
# Epoch [77/125], Average_loss: 1.2844
# Training: Batch 1/3. Loss of 1.1457, cover loss of 0.0080, secret loss of 1.1377
# Training: Batch 2/3. Loss of 1.3158, cover loss of 0.0081, secret loss of 1.3077
# Training: Batch 3/3. Loss of 1.2931, cover loss of 0.0069, secret loss of 1.2862
# Epoch [78/125], Average_loss: 1.2515
# Training: Batch 1/3. Loss of 1.4090, cover loss of 0.0058, secret loss of 1.4032
# Training: Batch 2/3. Loss of 1.4741, cover loss of 0.0064, secret loss of 1.4677
# Training: Batch 3/3. Loss of 1.1819, cover loss of 0.0071, secret loss of 1.1748
# Epoch [79/125], Average_loss: 1.3550
# Training: Batch 1/3. Loss of 1.3260, cover loss of 0.0075, secret loss of 1.3185
# Training: Batch 2/3. Loss of 1.3104, cover loss of 0.0067, secret loss of 1.3038
# Training: Batch 3/3. Loss of 1.3960, cover loss of 0.0054, secret loss of 1.3906
# Epoch [80/125], Average_loss: 1.3441
# Training: Batch 1/3. Loss of 1.4342, cover loss of 0.0058, secret loss of 1.4284
# Training: Batch 2/3. Loss of 1.2153, cover loss of 0.0062, secret loss of 1.2091
# Training: Batch 3/3. Loss of 1.3302, cover loss of 0.0053, secret loss of 1.3249
# Epoch [81/125], Average_loss: 1.3266
# Training: Batch 1/3. Loss of 1.3928, cover loss of 0.0058, secret loss of 1.3870
# Training: Batch 2/3. Loss of 1.2383, cover loss of 0.0067, secret loss of 1.2316
# Training: Batch 3/3. Loss of 1.3061, cover loss of 0.0072, secret loss of 1.2989
# Epoch [82/125], Average_loss: 1.3124
# Training: Batch 1/3. Loss of 1.4477, cover loss of 0.0058, secret loss of 1.4419
# Training: Batch 2/3. Loss of 1.2401, cover loss of 0.0058, secret loss of 1.2343
# Training: Batch 3/3. Loss of 1.2791, cover loss of 0.0066, secret loss of 1.2725
# Epoch [83/125], Average_loss: 1.3223
# Training: Batch 1/3. Loss of 1.2988, cover loss of 0.0057, secret loss of 1.2931
# Training: Batch 2/3. Loss of 1.2028, cover loss of 0.0064, secret loss of 1.1964
# Training: Batch 3/3. Loss of 1.3053, cover loss of 0.0054, secret loss of 1.2999
# Epoch [84/125], Average_loss: 1.2690
# Training: Batch 1/3. Loss of 1.2153, cover loss of 0.0065, secret loss of 1.2087
# Training: Batch 2/3. Loss of 1.3367, cover loss of 0.0054, secret loss of 1.3313
# Training: Batch 3/3. Loss of 1.2963, cover loss of 0.0055, secret loss of 1.2908
# Epoch [85/125], Average_loss: 1.2828
# Training: Batch 1/3. Loss of 1.4603, cover loss of 0.0063, secret loss of 1.4539
# Training: Batch 2/3. Loss of 1.3928, cover loss of 0.0044, secret loss of 1.3884
# Training: Batch 3/3. Loss of 1.2296, cover loss of 0.0046, secret loss of 1.2249
# Epoch [86/125], Average_loss: 1.3609
# Training: Batch 1/3. Loss of 1.3434, cover loss of 0.0044, secret loss of 1.3390
# Training: Batch 2/3. Loss of 1.2050, cover loss of 0.0052, secret loss of 1.1997
# Training: Batch 3/3. Loss of 1.2747, cover loss of 0.0049, secret loss of 1.2697
# Epoch [87/125], Average_loss: 1.2743
# Training: Batch 1/3. Loss of 1.2589, cover loss of 0.0059, secret loss of 1.2530
# Training: Batch 2/3. Loss of 1.4062, cover loss of 0.0048, secret loss of 1.4014
# Training: Batch 3/3. Loss of 1.3018, cover loss of 0.0052, secret loss of 1.2965
# Epoch [88/125], Average_loss: 1.3223
# Training: Batch 1/3. Loss of 1.2263, cover loss of 0.0049, secret loss of 1.2213
# Training: Batch 2/3. Loss of 1.4091, cover loss of 0.0053, secret loss of 1.4039
# Training: Batch 3/3. Loss of 1.4509, cover loss of 0.0055, secret loss of 1.4454
# Epoch [89/125], Average_loss: 1.3621
# Training: Batch 1/3. Loss of 1.1985, cover loss of 0.0078, secret loss of 1.1908
# Training: Batch 2/3. Loss of 1.3014, cover loss of 0.0093, secret loss of 1.2921
# Training: Batch 3/3. Loss of 1.3386, cover loss of 0.0083, secret loss of 1.3303
# Epoch [90/125], Average_loss: 1.2795
# Training: Batch 1/3. Loss of 1.3171, cover loss of 0.0069, secret loss of 1.3102
# Training: Batch 2/3. Loss of 1.3564, cover loss of 0.0064, secret loss of 1.3500
# Training: Batch 3/3. Loss of 1.2867, cover loss of 0.0066, secret loss of 1.2801
# Epoch [91/125], Average_loss: 1.3201
# Training: Batch 1/3. Loss of 1.2928, cover loss of 0.0066, secret loss of 1.2862
# Training: Batch 2/3. Loss of 1.1322, cover loss of 0.0084, secret loss of 1.1237
# Training: Batch 3/3. Loss of 1.3669, cover loss of 0.0073, secret loss of 1.3595
# Epoch [92/125], Average_loss: 1.2639
# Training: Batch 1/3. Loss of 1.4850, cover loss of 0.0051, secret loss of 1.4799
# Training: Batch 2/3. Loss of 1.2984, cover loss of 0.0053, secret loss of 1.2931
# Training: Batch 3/3. Loss of 1.2344, cover loss of 0.0073, secret loss of 1.2272
# Epoch [93/125], Average_loss: 1.3393
# Training: Batch 1/3. Loss of 1.3931, cover loss of 0.0061, secret loss of 1.3870
# Training: Batch 2/3. Loss of 1.2449, cover loss of 0.0047, secret loss of 1.2402
# Training: Batch 3/3. Loss of 1.1435, cover loss of 0.0058, secret loss of 1.1377
# Epoch [94/125], Average_loss: 1.2605
# Training: Batch 1/3. Loss of 1.3560, cover loss of 0.0047, secret loss of 1.3513
# Training: Batch 2/3. Loss of 1.3662, cover loss of 0.0056, secret loss of 1.3606
# Training: Batch 3/3. Loss of 1.4476, cover loss of 0.0048, secret loss of 1.4428
# Epoch [95/125], Average_loss: 1.3899
# Training: Batch 1/3. Loss of 1.3306, cover loss of 0.0055, secret loss of 1.3251
# Training: Batch 2/3. Loss of 1.3146, cover loss of 0.0057, secret loss of 1.3089
# Training: Batch 3/3. Loss of 1.4363, cover loss of 0.0048, secret loss of 1.4314
# Epoch [96/125], Average_loss: 1.3605
# Training: Batch 1/3. Loss of 1.3601, cover loss of 0.0047, secret loss of 1.3554
# Training: Batch 2/3. Loss of 1.3175, cover loss of 0.0043, secret loss of 1.3132
# Training: Batch 3/3. Loss of 1.3017, cover loss of 0.0049, secret loss of 1.2968
# Epoch [97/125], Average_loss: 1.3265
# Training: Batch 1/3. Loss of 1.3515, cover loss of 0.0052, secret loss of 1.3463
# Training: Batch 2/3. Loss of 1.3476, cover loss of 0.0051, secret loss of 1.3425
# Training: Batch 3/3. Loss of 1.2032, cover loss of 0.0048, secret loss of 1.1985
# Epoch [98/125], Average_loss: 1.3008
# Training: Batch 1/3. Loss of 1.2563, cover loss of 0.0054, secret loss of 1.2510
# Training: Batch 2/3. Loss of 1.4221, cover loss of 0.0045, secret loss of 1.4176
# Training: Batch 3/3. Loss of 1.2288, cover loss of 0.0051, secret loss of 1.2237
# Epoch [99/125], Average_loss: 1.3024
# Training: Batch 1/3. Loss of 1.2912, cover loss of 0.0044, secret loss of 1.2868
# Training: Batch 2/3. Loss of 1.3775, cover loss of 0.0041, secret loss of 1.3734
# Training: Batch 3/3. Loss of 1.3884, cover loss of 0.0046, secret loss of 1.3838
# Epoch [100/125], Average_loss: 1.3524
# Training: Batch 1/3. Loss of 1.2338, cover loss of 0.0046, secret loss of 1.2292
# Training: Batch 2/3. Loss of 1.4037, cover loss of 0.0039, secret loss of 1.3998
# Training: Batch 3/3. Loss of 1.2935, cover loss of 0.0047, secret loss of 1.2888
# Epoch [101/125], Average_loss: 1.3103
# Training: Batch 1/3. Loss of 1.4302, cover loss of 0.0043, secret loss of 1.4260
# Training: Batch 2/3. Loss of 1.4413, cover loss of 0.0051, secret loss of 1.4362
# Training: Batch 3/3. Loss of 1.2129, cover loss of 0.0038, secret loss of 1.2091
# Epoch [102/125], Average_loss: 1.3615
# Training: Batch 1/3. Loss of 1.2481, cover loss of 0.0049, secret loss of 1.2432
# Training: Batch 2/3. Loss of 1.4678, cover loss of 0.0040, secret loss of 1.4638
# Training: Batch 3/3. Loss of 1.2730, cover loss of 0.0052, secret loss of 1.2678
# Epoch [103/125], Average_loss: 1.3297
# Training: Batch 1/3. Loss of 1.1980, cover loss of 0.0058, secret loss of 1.1922
# Training: Batch 2/3. Loss of 1.5939, cover loss of 0.0044, secret loss of 1.5895
# Training: Batch 3/3. Loss of 1.2513, cover loss of 0.0036, secret loss of 1.2478
# Epoch [104/125], Average_loss: 1.3478
# Training: Batch 1/3. Loss of 1.3789, cover loss of 0.0049, secret loss of 1.3740
# Training: Batch 2/3. Loss of 1.3020, cover loss of 0.0045, secret loss of 1.2975
# Training: Batch 3/3. Loss of 1.2640, cover loss of 0.0053, secret loss of 1.2587
# Epoch [105/125], Average_loss: 1.3150
# Training: Batch 1/3. Loss of 1.2433, cover loss of 0.0048, secret loss of 1.2385
# Training: Batch 2/3. Loss of 1.3322, cover loss of 0.0042, secret loss of 1.3280
# Training: Batch 3/3. Loss of 1.1998, cover loss of 0.0040, secret loss of 1.1958
# Epoch [106/125], Average_loss: 1.2584
# Training: Batch 1/3. Loss of 1.3103, cover loss of 0.0042, secret loss of 1.3061
# Training: Batch 2/3. Loss of 1.3063, cover loss of 0.0038, secret loss of 1.3025
# Training: Batch 3/3. Loss of 1.3659, cover loss of 0.0041, secret loss of 1.3618
# Epoch [107/125], Average_loss: 1.3275
# Training: Batch 1/3. Loss of 1.1399, cover loss of 0.0043, secret loss of 1.1356
# Training: Batch 2/3. Loss of 1.2401, cover loss of 0.0044, secret loss of 1.2357
# Training: Batch 3/3. Loss of 1.3160, cover loss of 0.0039, secret loss of 1.3121
# Epoch [108/125], Average_loss: 1.2320
# Training: Batch 1/3. Loss of 1.2583, cover loss of 0.0044, secret loss of 1.2539
# Training: Batch 2/3. Loss of 1.3154, cover loss of 0.0035, secret loss of 1.3119
# Training: Batch 3/3. Loss of 1.4482, cover loss of 0.0037, secret loss of 1.4445
# Epoch [109/125], Average_loss: 1.3406
# Training: Batch 1/3. Loss of 1.2889, cover loss of 0.0051, secret loss of 1.2838
# Training: Batch 2/3. Loss of 1.2006, cover loss of 0.0039, secret loss of 1.1967
# Training: Batch 3/3. Loss of 1.3255, cover loss of 0.0042, secret loss of 1.3214
# Epoch [110/125], Average_loss: 1.2717
# Training: Batch 1/3. Loss of 1.2197, cover loss of 0.0036, secret loss of 1.2161
# Training: Batch 2/3. Loss of 1.2573, cover loss of 0.0052, secret loss of 1.2521
# Training: Batch 3/3. Loss of 1.3597, cover loss of 0.0075, secret loss of 1.3522
# Epoch [111/125], Average_loss: 1.2789
# Training: Batch 1/3. Loss of 1.2593, cover loss of 0.0090, secret loss of 1.2503
# Training: Batch 2/3. Loss of 1.3777, cover loss of 0.0089, secret loss of 1.3688
# Training: Batch 3/3. Loss of 1.3746, cover loss of 0.0069, secret loss of 1.3677
# Epoch [112/125], Average_loss: 1.3372
# Training: Batch 1/3. Loss of 1.3654, cover loss of 0.0047, secret loss of 1.3607
# Training: Batch 2/3. Loss of 1.2132, cover loss of 0.0059, secret loss of 1.2073
# Training: Batch 3/3. Loss of 1.3939, cover loss of 0.0058, secret loss of 1.3880
# Epoch [113/125], Average_loss: 1.3242
# Training: Batch 1/3. Loss of 1.3659, cover loss of 0.0043, secret loss of 1.3616
# Training: Batch 2/3. Loss of 1.2913, cover loss of 0.0052, secret loss of 1.2861
# Training: Batch 3/3. Loss of 1.3461, cover loss of 0.0074, secret loss of 1.3387
# Epoch [114/125], Average_loss: 1.3344
# Training: Batch 1/3. Loss of 1.1774, cover loss of 0.0063, secret loss of 1.1711
# Training: Batch 2/3. Loss of 1.2867, cover loss of 0.0040, secret loss of 1.2827
# Training: Batch 3/3. Loss of 1.2804, cover loss of 0.0043, secret loss of 1.2761
# Epoch [115/125], Average_loss: 1.2482
# Training: Batch 1/3. Loss of 1.2252, cover loss of 0.0055, secret loss of 1.2198
# Training: Batch 2/3. Loss of 1.5036, cover loss of 0.0043, secret loss of 1.4992
# Training: Batch 3/3. Loss of 1.0926, cover loss of 0.0041, secret loss of 1.0884
# Epoch [116/125], Average_loss: 1.2738
# Training: Batch 1/3. Loss of 1.0883, cover loss of 0.0053, secret loss of 1.0831
# Training: Batch 2/3. Loss of 1.3719, cover loss of 0.0059, secret loss of 1.3661
# Training: Batch 3/3. Loss of 1.1981, cover loss of 0.0059, secret loss of 1.1922
# Epoch [117/125], Average_loss: 1.2195
# Training: Batch 1/3. Loss of 1.2575, cover loss of 0.0042, secret loss of 1.2533
# Training: Batch 2/3. Loss of 1.4189, cover loss of 0.0048, secret loss of 1.4142
# Training: Batch 3/3. Loss of 1.1433, cover loss of 0.0038, secret loss of 1.1394
# Epoch [118/125], Average_loss: 1.2732
# Training: Batch 1/3. Loss of 1.2163, cover loss of 0.0037, secret loss of 1.2126
# Training: Batch 2/3. Loss of 1.2811, cover loss of 0.0040, secret loss of 1.2771
# Training: Batch 3/3. Loss of 1.3191, cover loss of 0.0040, secret loss of 1.3151
# Epoch [119/125], Average_loss: 1.2722
# Training: Batch 1/3. Loss of 1.2122, cover loss of 0.0040, secret loss of 1.2082
# Training: Batch 2/3. Loss of 1.3492, cover loss of 0.0041, secret loss of 1.3450
# Training: Batch 3/3. Loss of 1.3962, cover loss of 0.0041, secret loss of 1.3922
# Epoch [120/125], Average_loss: 1.3192
# Training: Batch 1/3. Loss of 1.3200, cover loss of 0.0035, secret loss of 1.3166
# Training: Batch 2/3. Loss of 1.3496, cover loss of 0.0038, secret loss of 1.3458
# Training: Batch 3/3. Loss of 1.4125, cover loss of 0.0034, secret loss of 1.4091
# Epoch [121/125], Average_loss: 1.3607
# Training: Batch 1/3. Loss of 1.3167, cover loss of 0.0038, secret loss of 1.3129
# Training: Batch 2/3. Loss of 1.2388, cover loss of 0.0041, secret loss of 1.2348
# Training: Batch 3/3. Loss of 1.2987, cover loss of 0.0039, secret loss of 1.2948
# Epoch [122/125], Average_loss: 1.2847
# Training: Batch 1/3. Loss of 1.3943, cover loss of 0.0037, secret loss of 1.3906
# Training: Batch 2/3. Loss of 1.1829, cover loss of 0.0034, secret loss of 1.1795
# Training: Batch 3/3. Loss of 1.3273, cover loss of 0.0037, secret loss of 1.3236
# Epoch [123/125], Average_loss: 1.3015
# Training: Batch 1/3. Loss of 1.3603, cover loss of 0.0036, secret loss of 1.3567
# Training: Batch 2/3. Loss of 1.3235, cover loss of 0.0039, secret loss of 1.3196
# Training: Batch 3/3. Loss of 1.1450, cover loss of 0.0038, secret loss of 1.1411
# Epoch [124/125], Average_loss: 1.2762
# Training: Batch 1/3. Loss of 1.4103, cover loss of 0.0037, secret loss of 1.4066
# Training: Batch 2/3. Loss of 1.2515, cover loss of 0.0040, secret loss of 1.2474
# Training: Batch 3/3. Loss of 1.2677, cover loss of 0.0051, secret loss of 1.2626
# Epoch [125/125], Average_loss: 1.3098

# %%
net.eval()

test_losses = []
# Show images
for idx, test_batch in enumerate(test_loader):
     # Saves images
    data, _ = test_batch
    data = data.to(DEVICE)

    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images
    test_secret = torch.tensor(test_secret)
    test_cover = torch.tensor(test_cover)
    # Compute output
    test_hidden, test_output = net(test_secret, test_cover)
    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, beta)
    
#     diff_S, diff_C = np.abs(np.array(test_output.data[0]) - np.array(test_secret.data[0])), np.abs(np.array(test_hidden.data[0]) - np.array(test_cover.data[0]))
    
#     print (diff_S, diff_C)
    test_secret = torch.tensor(test_secret).to('cpu')
    test_cover = torch.tensor(test_cover).to('cpu')
    test_hidden, test_output = test_hidden.cpu(), test_output.cpu() 
    
    
    if idx <500:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(torch.Tensor.item(test_loss.data), torch.Tensor.item(loss_secret.data), torch.Tensor.item(loss_cover.data)))

        # Creates img tensor
        imgs = [test_secret.data, test_output.data, test_cover.data, test_hidden.data]
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)
        
    test_losses.append(torch.Tensor.item(test_loss.data))
        
mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 1.04
# Loss on secret: 1.04
# Loss on cover: 0.00
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 1.10
# Loss on secret: 1.10
# Loss on cover: 0.00
# Total loss: 1.24
# Loss on secret: 1.24
# Loss on cover: 0.00
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 1.35
# Loss on secret: 1.35
# Loss on cover: 0.00
# Total loss: 1.04
# Loss on secret: 1.03
# Loss on cover: 0.01
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.93
# Loss on secret: 0.93
# Loss on cover: 0.00
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 1.28
# Loss on secret: 1.27
# Loss on cover: 0.00
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 1.09
# Loss on secret: 1.09
# Loss on cover: 0.00
# Total loss: 1.10
# Loss on secret: 1.10
# Loss on cover: 0.00
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 1.31
# Loss on secret: 1.30
# Loss on cover: 0.00
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 1.11
# Loss on secret: 1.10
# Loss on cover: 0.00
# Total loss: 0.89
# Loss on secret: 0.89
# Loss on cover: 0.00
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Average loss on test set: 1.12
